# %%
import itertools
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.ticker as ticker
from sklearn import preprocessing
# %matplotlib inline

# %%
# !conda install -c anaconda xlrd --yes
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
df = pd.read_csv (r'C:\Users\OLUFUNMILAYO\Downloads\Arrest_Data_from_2010_to_2019.csv')   #read the csv file (put 'r' before the path string to address any special characters, such as '\'). Don't forget to put the file name at the end of the path + ".csv"
df.head()
# Out:
#    Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  Age  \
# 0  191811472  05/03/2019  1700.0       18  Southeast                1802   23
# 1    5614161  04/29/2019  1040.0        8    West LA                 842   41
# 2    5615197  04/30/2019   615.0        6  Hollywood                 663   27
# 3    5615701  04/30/2019  1100.0        9   Van Nuys                 901    2
# 4    5615929  04/30/2019  1550.0       20    Olympic                2049   41
#
#   Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 0        F            B                NaN                      NaN
# 1        M            H                3.0                  Robbery
# 2        M            O                5.0                 Burglary
# 3        F            H                NaN                      NaN
# 4        M            W                4.0       Aggravated Assault
#
#   Arrest Type Code       Charge Charge Description  \
# ...

# %%
df.shape
# Out:
# (1310127, 17)

# %%
df['Arrest Date'] = pd.to_datetime(df['Arrest Date'])
df.head()
# Out:
#    Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  Age  \
# 0  191811472  2019-05-03  1700.0       18  Southeast                1802   23
# 1    5614161  2019-04-29  1040.0        8    West LA                 842   41
# 2    5615197  2019-04-30   615.0        6  Hollywood                 663   27
# 3    5615701  2019-04-30  1100.0        9   Van Nuys                 901    2
# 4    5615929  2019-04-30  1550.0       20    Olympic                2049   41
#
#   Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 0        F            B                NaN                      NaN
# 1        M            H                3.0                  Robbery
# 2        M            O                5.0                 Burglary
# 3        F            H                NaN                      NaN
# 4        M            W                4.0       Aggravated Assault
#
#   Arrest Type Code       Charge Charge Description  \
# ...

# %%
df['year_only'] = df['Arrest Date'].dt.year
df.head()
# Out:
#    Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  Age  \
# 0  191811472  2019-05-03  1700.0       18  Southeast                1802   23
# 1    5614161  2019-04-29  1040.0        8    West LA                 842   41
# 2    5615197  2019-04-30   615.0        6  Hollywood                 663   27
# 3    5615701  2019-04-30  1100.0        9   Van Nuys                 901    2
# 4    5615929  2019-04-30  1550.0       20    Olympic                2049   41
#
#   Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 0        F            B                NaN                      NaN
# 1        M            H                3.0                  Robbery
# 2        M            O                5.0                 Burglary
# 3        F            H                NaN                      NaN
# 4        M            W                4.0       Aggravated Assault
#
#   Arrest Type Code       Charge Charge Description  \
# ...

# %%
# select column
dfprobcharge = df[(df['Charge Group Code']!=99)]

# %%
dfprobcharge.shape
# Out:
# (1310120, 18)

# %%
dfprobcharge.head()
# Out:
#    Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  Age  \
# 0  191811472  2019-05-03  1700.0       18  Southeast                1802   23
# 1    5614161  2019-04-29  1040.0        8    West LA                 842   41
# 2    5615197  2019-04-30   615.0        6  Hollywood                 663   27
# 3    5615701  2019-04-30  1100.0        9   Van Nuys                 901    2
# 4    5615929  2019-04-30  1550.0       20    Olympic                2049   41
#
#   Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 0        F            B                NaN                      NaN
# 1        M            H                3.0                  Robbery
# 2        M            O                5.0                 Burglary
# 3        F            H                NaN                      NaN
# 4        M            W                4.0       Aggravated Assault
#
#   Arrest Type Code       Charge Charge Description  \
# ...

# %%
dfprobcharge.dropna(subset=["Charge Group Code"], axis=0, inplace=True)
# Out:
# C:\Users\OLUFUNMILAYO\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfprobcharge.head()
# Out:
#    Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  Age  \
# 1    5614161  2019-04-29  1040.0        8    West LA                 842   41
# 2    5615197  2019-04-30   615.0        6  Hollywood                 663   27
# 4    5615929  2019-04-30  1550.0       20    Olympic                2049   41
# 5  190112234  2019-04-16  1450.0        1    Central                 123   54
# 6  190112235  2019-04-26  1505.0        1    Central                 152   57
#
#   Sex Code Descent Code  Charge Group Code        Charge Group Description  \
# 1        M            H                3.0                         Robbery
# 2        M            O                5.0                        Burglary
# 4        M            W                4.0              Aggravated Assault
# 5        F            H               24.0  Miscellaneous Other Violations
# 6        M            H               18.0                      Drunkeness
#
# ...

# %%
dfprobcharge_1 =dfprobcharge[(dfprobcharge['year_only']==2018)]

# %%
dfprobcharge_1.shape
# Out:
# (91888, 18)

# %%
dfprobcharge_1.head()
# Out:
#      Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  \
# 156    5213460  2018-01-24  1930.0        6  Hollywood                 668
# 157    5257944  2018-03-15   310.0        7   Wilshire                 743
# 158    5328813  2018-06-01  1800.0        3  Southwest                 356
# 159    5336331  2018-06-10   200.0       13     Newton                1364
# 160    5360731  2018-07-07  2330.0       18  Southeast                1832
#
#      Age Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 156   29        M            H               10.0       Fraud/Embezzlement
# 157   33        F            O                1.0                 Homicide
# 158   44        F            B               16.0       Narcotic Drug Laws
# 159   23        M            H               12.0      Weapon (carry/poss)
# 160   32        M            B               12.0      Weapon (carry/poss)
#
# ...

# %%
dfprobcharge_1.drop(['Report ID','Arrest Date','Time','Area Name','Age','Reporting District', 'Sex Code', 'Descent Code', 'Charge Group Description', 'Arrest Type Code', 'Charge', 'Charge Description', 'Address', 'Cross Street','Location', 'year_only'], axis=1, inplace=True)
# Out:
# C:\Users\OLUFUNMILAYO\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
dfprobcharge_1.shape
# Out:
# (91888, 2)

# %%
dfprobcharge_1.head()
# Out:
#      Area ID  Charge Group Code
# 156        6               10.0
# 157        7                1.0
# 158        3               16.0
# 159       13               12.0
# 160       18               12.0

# %%
dfprobcharge_2= dfprobcharge_1.groupby(['Area ID']).count().reset_index()

# %%
dfprobcharge_2
# Out:
#     Area ID  Charge Group Code
# 0         1              10305
# 1         2               5022
# 2         3               5557
# 3         4               3253
# 4         5               3595
# 5         6               7129
# 6         7               2419
# 7         8               2454
# 8         9               5375
# 9        10               3427
# 10       11               3148
# 11       12               6069
# 12       13               5247
# 13       14               4927
# 14       15               4019
# 15       16               2853
# 16       17               2987
# 17       18               3530
# 18       19               3872
# 19       20               3785
# 20       21               2915

# %%
dfprobcharge_4 =dfprobcharge_2.assign(Prob1 = dfprobcharge_2['Charge Group Code']/91888)

# %%
dfprobcharge_4
# Out:
#     Area ID  Charge Group Code     Prob1
# 0         1              10305  0.112147
# 1         2               5022  0.054653
# 2         3               5557  0.060476
# 3         4               3253  0.035402
# 4         5               3595  0.039124
# 5         6               7129  0.077584
# 6         7               2419  0.026326
# 7         8               2454  0.026706
# 8         9               5375  0.058495
# 9        10               3427  0.037295
# 10       11               3148  0.034259
# 11       12               6069  0.066048
# 12       13               5247  0.057102
# 13       14               4927  0.053620
# 14       15               4019  0.043738
# 15       16               2853  0.031049
# 16       17               2987  0.032507
# 17       18               3530  0.038416
# 18       19               3872  0.042138
# 19       20               3785  0.041191
# 20       21               2915  0.031723

# %%
dfprobcharge_4.head()
# Out:
#    Area ID  Charge Group Code     Prob1
# 0        1              10305  0.112147
# 1        2               5022  0.054653
# 2        3               5557  0.060476
# 3        4               3253  0.035402
# 4        5               3595  0.039124

# %%
dfprobcharge_4.dtypes
# Out:
# Area ID                int64
# Charge Group Code      int64
# Prob1                float64
# dtype: object

# %%
dfprobcharge_7 =dfprobcharge_4.assign(Code1 = dfprobcharge_4['Charge Group Code']-1)

# %%
dfprobcharge_7.head()
# Out:
#    Area ID  Charge Group Code     Prob1  Code1
# 0        1              10305  0.112147  10304
# 1        2               5022  0.054653   5021
# 2        3               5557  0.060476   5556
# 3        4               3253  0.035402   3252
# 4        5               3595  0.039124   3594

# %%
dfprobcharge_8 =dfprobcharge_7.assign(Prob3 = dfprobcharge_7['Code1']/91888)

# %%
dfprobcharge_8
# Out:
#     Area ID  Charge Group Code     Prob1  Code1     Prob3
# 0         1              10305  0.112147  10304  0.112137
# 1         2               5022  0.054653   5021  0.054643
# 2         3               5557  0.060476   5556  0.060465
# 3         4               3253  0.035402   3252  0.035391
# 4         5               3595  0.039124   3594  0.039113
# 5         6               7129  0.077584   7128  0.077573
# 6         7               2419  0.026326   2418  0.026315
# 7         8               2454  0.026706   2453  0.026696
# 8         9               5375  0.058495   5374  0.058484
# 9        10               3427  0.037295   3426  0.037285
# 10       11               3148  0.034259   3147  0.034248
# 11       12               6069  0.066048   6068  0.066037
# 12       13               5247  0.057102   5246  0.057091
# 13       14               4927  0.053620   4926  0.053609
# 14       15               4019  0.043738   4018  0.043727
# ...

# %%
dfprobcharge_9 =dfprobcharge_8.assign(Prob4 = dfprobcharge_8['Prob1'] *dfprobcharge_8['Prob3'])

# %%
dfprobcharge_9.head()
# Out:
#    Area ID  Charge Group Code     Prob1  Code1     Prob3     Prob4
# 0        1              10305  0.112147  10304  0.112137  0.012576
# 1        2               5022  0.054653   5021  0.054643  0.002986
# 2        3               5557  0.060476   5556  0.060465  0.003657
# 3        4               3253  0.035402   3252  0.035391  0.001253
# 4        5               3595  0.039124   3594  0.039113  0.001530

# %%
dfprobcharge_9.sort_values(['Prob4'], ascending=False, axis=0, inplace=True)

# %%
df_top51 = dfprobcharge_9.head()

# %%
df_top51
# Out:
#     Area ID  Charge Group Code     Prob1  Code1     Prob3     Prob4
# 0         1              10305  0.112147  10304  0.112137  0.012576
# 5         6               7129  0.077584   7128  0.077573  0.006018
# 11       12               6069  0.066048   6068  0.066037  0.004362
# 2         3               5557  0.060476   5556  0.060465  0.003657
# 8         9               5375  0.058495   5374  0.058484  0.003421

# %%
dfprobcharge_3 = dfprobcharge_1.groupby(['Charge Group Code']).count().reset_index()

# %%
dfprobcharge_3
# Out:
#     Charge Group Code  Area ID
# 0                 1.0      274
# 1                 2.0      315
# 2                 3.0     2787
# 3                 4.0     9231
# 4                 5.0     1958
# 5                 6.0     5129
# 6                 7.0     3257
# 7                 8.0     7907
# 8                 9.0      415
# 9                10.0     1061
# 10               11.0      455
# 11               12.0     3396
# 12               13.0     2970
# 13               14.0     1179
# 14               15.0      923
# 15               16.0    10697
# 16               17.0     3481
# 17               18.0     3769
# 18               19.0       98
# 19               20.0     2536
# 20               21.0      175
# 21               22.0     8918
# 22               23.0     3565
# 23               24.0    17023
# 24               25.0       25
# 25               26.0      198
# 26               27.0       72
# 27               29.0       74

# %%
dfprobcharge_5 =dfprobcharge_3.assign(Prob2 = dfprobcharge_3['Area ID']/91888)

# %%
dfprobcharge_5
# Out:
#     Charge Group Code  Area ID     Prob2
# 0                 1.0      274  0.002982
# 1                 2.0      315  0.003428
# 2                 3.0     2787  0.030330
# 3                 4.0     9231  0.100459
# 4                 5.0     1958  0.021309
# 5                 6.0     5129  0.055818
# 6                 7.0     3257  0.035445
# 7                 8.0     7907  0.086050
# 8                 9.0      415  0.004516
# 9                10.0     1061  0.011547
# 10               11.0      455  0.004952
# 11               12.0     3396  0.036958
# 12               13.0     2970  0.032322
# 13               14.0     1179  0.012831
# 14               15.0      923  0.010045
# 15               16.0    10697  0.116413
# 16               17.0     3481  0.037883
# 17               18.0     3769  0.041017
# 18               19.0       98  0.001067
# 19               20.0     2536  0.027599
# 20               21.0      175  0.001904
# 21               22.0     8918  0.097053
# ...

# %%
dfprobcharge_5.head()
# Out:
#    Charge Group Code  Area ID     Prob2
# 0                1.0      274  0.002982
# 1                2.0      315  0.003428
# 2                3.0     2787  0.030330
# 3                4.0     9231  0.100459
# 4                5.0     1958  0.021309

# %%
dfprobcharge_5.sort_values(['Prob2'], ascending=False, axis=0, inplace=True)

# %%
df_top52 = dfprobcharge_5.head()

# %%
df_top52
# Out:
#     Charge Group Code  Area ID     Prob2
# 23               24.0    17023  0.185258
# 15               16.0    10697  0.116413
# 3                 4.0     9231  0.100459
# 21               22.0     8918  0.097053
# 7                 8.0     7907  0.086050

# %%
dfprobcharge_10= df.groupby(['Area Name']).count().reset_index()

# %%
dfprobcharge_10
# Out:
#       Area Name  Report ID  Arrest Date    Time  Area ID  Reporting District  \
# 0   77th Street      71968        71968   71967    71968               71968
# 1       Central     129608       129608  129601   129608              129608
# 2    Devonshire      40183        40183   40178    40183               40183
# 3      Foothill      47933        47933   47929    47933               47933
# 4        Harbor      48141        48141   48131    48141               48141
# 5    Hollenbeck      43105        43105   43103    43105               43105
# 6     Hollywood     121953       121953  121904   121953              121953
# 7       Mission      65840        65840   65826    65840               65840
# 8   N Hollywood      64332        64332   64331    64332               64332
# 9        Newton      69860        69860   69858    69860               69860
# 10    Northeast      50722        50722   50712    50722               50722
# ...

# %%
dfprobcharge_11= df.groupby(['Charge Group Description']).count().reset_index()

# %%
dfprobcharge_11
# Out:
#           Charge Group Description  Report ID  Arrest Date    Time  Area ID  \
# 0             Against Family/Child       7311         7311    7311     7311
# 1               Aggravated Assault      85682        85682   85682    85682
# 2                         Burglary      24255        24255   24255    24255
# 3               Disorderly Conduct      36987        36987   36979    36987
# 4             Disturbing the Peace       2957         2957    2956     2957
# 5          Driving Under Influence     120206       120206  120206   120206
# 6                       Drunkeness     115567       115567  115520   115567
# 7                 Federal Offenses        235          235     235      235
# 8              Forgery/Counterfeit       6949         6949    6949     6949
# 9               Fraud/Embezzlement       9574         9574    9574     9574
# 10                        Gambling       2318         2318    2318     2318
# ...

# %%
dfprobcharge.head()
# Out:
#    Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  Age  \
# 1    5614161  2019-04-29  1040.0        8    West LA                 842   41
# 2    5615197  2019-04-30   615.0        6  Hollywood                 663   27
# 4    5615929  2019-04-30  1550.0       20    Olympic                2049   41
# 5  190112234  2019-04-16  1450.0        1    Central                 123   54
# 6  190112235  2019-04-26  1505.0        1    Central                 152   57
#
#   Sex Code Descent Code  Charge Group Code        Charge Group Description  \
# 1        M            H                3.0                         Robbery
# 2        M            O                5.0                        Burglary
# 4        M            W                4.0              Aggravated Assault
# 5        F            H               24.0  Miscellaneous Other Violations
# 6        M            H               18.0                      Drunkeness
#
# ...

# %%
dfprobchargu_1 =dfprobcharge[(dfprobcharge['year_only']==2018)]

# %%
dfprobchargu_1.drop(['Arrest Date','Time','Age','Reporting District', 'Sex Code', 'Descent Code', 'Charge Group Description', 'Arrest Type Code', 'Charge', 'Charge Description', 'Address', 'Cross Street','Location', 'year_only'], axis=1, inplace=True)
# Out:
# C:\Users\OLUFUNMILAYO\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
dfprobchargu_1.shape
# Out:
# (91888, 4)

# %%
dfprobchargu_1
# Out:
#          Report ID  Area ID    Area Name  Charge Group Code
# 156        5213460        6    Hollywood               10.0
# 157        5257944        7     Wilshire                1.0
# 158        5328813        3    Southwest               16.0
# 159        5336331       13       Newton               12.0
# 160        5360731       18    Southeast               12.0
# 161        5404690       18    Southeast               12.0
# 162        5406551       18    Southeast               12.0
# 165        5419122       12  77th Street                8.0
# 166        5430543       13       Newton               24.0
# 167        5449454        1      Central                7.0
# 172        5449463        1      Central                7.0
# 173        5452727        1      Central                7.0
# 174        5456681        6    Hollywood                4.0
# 175        5460361       12  77th Street                7.0
# 176        5464308        1      Central                7.0
# ...

# %%
dfprobchargu_2 = dfprobchargu_1.groupby(['Area ID', 'Charge Group Code']).size().reset_index()

# %%
dfprobchargu_2.head()
# Out:
#    Area ID  Charge Group Code    0
# 0        1                1.0   18
# 1        1                2.0   27
# 2        1                3.0  207
# 3        1                4.0  627
# 4        1                5.0  123

# %%
dfprobchargu_2
# Out:
#      Area ID  Charge Group Code     0
# 0          1                1.0    18
# 1          1                2.0    27
# 2          1                3.0   207
# 3          1                4.0   627
# 4          1                5.0   123
# 5          1                6.0   642
# 6          1                7.0   124
# 7          1                8.0   719
# 8          1                9.0    56
# 9          1               10.0   108
# 10         1               11.0    18
# 11         1               12.0   183
# 12         1               13.0    57
# 13         1               14.0   172
# 14         1               15.0    19
# 15         1               16.0  1494
# 16         1               17.0  1166
# 17         1               18.0   539
# 18         1               19.0    12
# 19         1               20.0  1251
# 20         1               21.0     6
# 21         1               22.0   418
# 22         1               23.0   250
# 23         1               24.0  2053
# ...

# %%
dfprobchargu_2.shape
# Out:
# (560, 3)

# %%
dfprobchargu_2.columns = list(map(str, dfprobchargu_2.columns))

# %%
dfprobchargu_2.rename(columns={'O':'Total'}, inplace=True)

# %%
dfprobchargu_2.columns = list(map(str, dfprobchargu_2.columns))

# %%
dfprobchargu_2.head()
# Out:
#    Area ID  Charge Group Code    0
# 0        1                1.0   18
# 1        1                2.0   27
# 2        1                3.0  207
# 3        1                4.0  627
# 4        1                5.0  123

# %%
dfprobchargu_3 = dfprobchargu_2.assign(Prob6 = dfprobchargu_2['0']/560)

# %%
dfprobchargu_3
# Out:
#      Area ID  Charge Group Code     0     Prob6
# 0          1                1.0    18  0.032143
# 1          1                2.0    27  0.048214
# 2          1                3.0   207  0.369643
# 3          1                4.0   627  1.119643
# 4          1                5.0   123  0.219643
# 5          1                6.0   642  1.146429
# 6          1                7.0   124  0.221429
# 7          1                8.0   719  1.283929
# 8          1                9.0    56  0.100000
# 9          1               10.0   108  0.192857
# 10         1               11.0    18  0.032143
# 11         1               12.0   183  0.326786
# 12         1               13.0    57  0.101786
# 13         1               14.0   172  0.307143
# 14         1               15.0    19  0.033929
# 15         1               16.0  1494  2.667857
# 16         1               17.0  1166  2.082143
# 17         1               18.0   539  0.962500
# 18         1               19.0    12  0.021429
# ...

# %%
dfprobchargu_4 =dfprobchargu_3.assign(Code5 = dfprobchargu_3['0']-1)

# %%
dfprobchargu_4.head()
# Out:
#    Area ID  Charge Group Code    0     Prob6  Code5
# 0        1                1.0   18  0.032143     17
# 1        1                2.0   27  0.048214     26
# 2        1                3.0  207  0.369643    206
# 3        1                4.0  627  1.119643    626
# 4        1                5.0  123  0.219643    122

# %%
dfprobchargu_5 = dfprobchargu_4.assign(Prob7 = dfprobchargu_4['0']/559)

# %%
dfprobchargu_5.head()
# Out:
#    Area ID  Charge Group Code    0     Prob6  Code5     Prob7
# 0        1                1.0   18  0.032143     17  0.032200
# 1        1                2.0   27  0.048214     26  0.048301
# 2        1                3.0  207  0.369643    206  0.370304
# 3        1                4.0  627  1.119643    626  1.121646
# 4        1                5.0  123  0.219643    122  0.220036

# %%
dfprobchargu_6 =dfprobchargu_5.assign(Prob8= dfprobchargu_5['Prob6'] *dfprobchargu_5['Prob7'])

# %%
dfprobchargu_6.shape
# Out:
# (560, 7)

# %%
dfprobchargu_6.head()
# Out:
#      Area ID  Charge Group Code     0     Prob6  Code5     Prob7      Prob8
# 23         1               24.0  2053  3.666071   2052  3.672630  13.464123
# 158        6               24.0  1820  3.250000   1819  3.255814  10.581395
# 15         1               16.0  1494  2.667857   1493  2.672630   7.130194
# 19         1               20.0  1251  2.233929   1250  2.237925   4.999364
# 150        6               16.0  1228  2.192857   1227  2.196780   4.817225

# %%
dfprobchargu_6.sort_values(['Prob8'], ascending=False, axis = 0, inplace=True)

# %%
df_top05 = dfprobchargu_6.head()

# %%
df_top05
# Out:
#      Area ID  Charge Group Code     0     Prob6  Code5     Prob7      Prob8
# 23         1               24.0  2053  3.666071   2052  3.672630  13.464123
# 158        6               24.0  1820  3.250000   1819  3.255814  10.581395
# 15         1               16.0  1494  2.667857   1493  2.672630   7.130194
# 19         1               20.0  1251  2.233929   1250  2.237925   4.999364
# 150        6               16.0  1228  2.192857   1227  2.196780   4.817225

# %%
df_top05.describe()
# Out:
#         Area ID  Charge Group Code            0     Prob6        Code5  \
# count  5.000000                5.0     5.000000  5.000000     5.000000
# mean   3.000000               20.0  1569.200000  2.802143  1568.200000
# std    2.738613                4.0   360.654544  0.644026   360.654544
# min    1.000000               16.0  1228.000000  2.192857  1227.000000
# 25%    1.000000               16.0  1251.000000  2.233929  1250.000000
# 50%    1.000000               20.0  1494.000000  2.667857  1493.000000
# 75%    6.000000               24.0  1820.000000  3.250000  1819.000000
# max    6.000000               24.0  2053.000000  3.666071  2052.000000
#
#           Prob7      Prob8
# count  5.000000   5.000000
# mean   2.807156   8.198460
# std    0.645178   3.748791
# min    2.196780   4.817225
# 25%    2.237925   4.999364
# 50%    2.672630   7.130194
# 75%    3.255814  10.581395
# max    3.672630  13.464123
