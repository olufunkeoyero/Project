# %%
import itertools
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.ticker as ticker
from sklearn import preprocessing
# %matplotlib inline

# %%
# !conda install -c anaconda xlrd --yes
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
df = pd.read_csv (r'C:\Users\OLUFUNMILAYO\Downloads\Arrest_Data_from_2010_to_2019.csv')   #read the csv file (put 'r' before the path string to address any special characters, such as '\'). Don't forget to put the file name at the end of the path + ".csv"
df.head()
# Out:
#    Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  Age  \
# 0  191811472  05/03/2019  1700.0       18  Southeast                1802   23
# 1    5614161  04/29/2019  1040.0        8    West LA                 842   41
# 2    5615197  04/30/2019   615.0        6  Hollywood                 663   27
# 3    5615701  04/30/2019  1100.0        9   Van Nuys                 901    2
# 4    5615929  04/30/2019  1550.0       20    Olympic                2049   41
#
#   Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 0        F            B                NaN                      NaN
# 1        M            H                3.0                  Robbery
# 2        M            O                5.0                 Burglary
# 3        F            H                NaN                      NaN
# 4        M            W                4.0       Aggravated Assault
#
#   Arrest Type Code       Charge Charge Description  \
# ...

# %%
df.shape
# Out:
# (1310127, 17)

# %%
df['Arrest Date'] = pd.to_datetime(df['Arrest Date'])
df.head()
# Out:
#    Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  Age  \
# 0  191811472  2019-05-03  1700.0       18  Southeast                1802   23
# 1    5614161  2019-04-29  1040.0        8    West LA                 842   41
# 2    5615197  2019-04-30   615.0        6  Hollywood                 663   27
# 3    5615701  2019-04-30  1100.0        9   Van Nuys                 901    2
# 4    5615929  2019-04-30  1550.0       20    Olympic                2049   41
#
#   Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 0        F            B                NaN                      NaN
# 1        M            H                3.0                  Robbery
# 2        M            O                5.0                 Burglary
# 3        F            H                NaN                      NaN
# 4        M            W                4.0       Aggravated Assault
#
#   Arrest Type Code       Charge Charge Description  \
# ...

# %%
df['year_only'] = df['Arrest Date'].dt.year
df.head()
# Out:
#    Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  Age  \
# 0  191811472  2019-05-03  1700.0       18  Southeast                1802   23
# 1    5614161  2019-04-29  1040.0        8    West LA                 842   41
# 2    5615197  2019-04-30   615.0        6  Hollywood                 663   27
# 3    5615701  2019-04-30  1100.0        9   Van Nuys                 901    2
# 4    5615929  2019-04-30  1550.0       20    Olympic                2049   41
#
#   Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 0        F            B                NaN                      NaN
# 1        M            H                3.0                  Robbery
# 2        M            O                5.0                 Burglary
# 3        F            H                NaN                      NaN
# 4        M            W                4.0       Aggravated Assault
#
#   Arrest Type Code       Charge Charge Description  \
# ...

# %%
df.shape
# Out:
# (1310127, 18)

# %%
dfpicoboul = df[df['Address'].str.contains("PICO")==True]

# %%
dfpicoboul.shape
# Out:
# (7819, 18)

# %%
dfpicoboul_1 =dfpicoboul[(dfpicoboul['year_only']==2018)]

# %%
dfpicoboul_1.shape
# Out:
# (613, 18)

# %%
dfpicoboul_1.head()
# Out:
#       Report ID Arrest Date    Time  Area ID Area Name  Reporting District  \
# 186     5485873  2018-12-01  1350.0       20   Olympic                2076
# 4739    5270090  2018-03-29   931.0        8   West LA                 836
# 6681  182016070  2018-08-08  1350.0       20   Olympic                2071
# 6754    5299360  2018-05-01   325.0       20   Olympic                2076
# 6764    5405832  2018-08-27   415.0        7  Wilshire                 753
#
#       Age Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 186    37        M            B                8.0           Other Assaults
# 4739   53        M            W                6.0                  Larceny
# 6681   28        M            H               18.0               Drunkeness
# 6754   33        M            H                5.0                 Burglary
# 6764   22        M            H                8.0           Other Assaults
#
# ...

# %%
dfpicoboul_1.drop(['Report ID','Arrest Date','Time','Area ID','Area Name','Age','Reporting District', 'Sex Code', 'Descent Code', 'Charge Group Code', 'Charge Group Description', 'Charge', 'Charge Description', 'Address', 'Cross Street','Arrest Type Code'], axis=1, inplace=True)
# Out:
# C:\Users\OLUFUNMILAYO\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
dfpicoboul_1.head()
# Out:
#                   Location  year_only
# 186   (34.0473, -118.2936)       2018
# 4739  (34.0524, -118.4248)       2018
# 6681   (34.0472, -118.309)       2018
# 6754  (34.0473, -118.2916)       2018
# 6764  (34.0515, -118.3667)       2018

# %%
dfpicoboul_1.shape
# Out:
# (613, 2)

# %%
dfpicoboul_1[dfpicoboul_1.Location != '(0,0)']
# Out:
#                      Location  year_only
# 186      (34.0473, -118.2936)       2018
# 4739     (34.0524, -118.4248)       2018
# 6681      (34.0472, -118.309)       2018
# 6754     (34.0473, -118.2916)       2018
# 6764     (34.0515, -118.3667)       2018
# 8772     (34.0473, -118.2891)       2018
# 10792    (34.0485, -118.3335)       2018
# 48595     (34.042, -118.2625)       2018
# 52701    (34.0401, -118.2668)       2018
# 59546    (34.0467, -118.2814)       2018
# 59550     (34.0472, -118.309)       2018
# 59620     (34.0452, -118.419)       2018
# 59677    (34.0369, -118.2607)       2018
# 59755    (34.0479, -118.3447)       2018
# 59847    (34.0437, -118.2748)       2018
# 421749   (34.0363, -118.2672)       2018
# 422058    (34.042, -118.2625)       2018
# 422449    (34.042, -118.2625)       2018
# 422741   (34.0389, -118.2643)       2018
# 423804   (34.0335, -118.2619)       2018
# 423847   (34.0395, -118.2656)       2018
# 424476    (34.042, -118.2625)       2018
# ...

# %%
dfpicoboul_1.drop(['year_only'], axis=1)
# Out:
#                      Location
# 186      (34.0473, -118.2936)
# 4739     (34.0524, -118.4248)
# 6681      (34.0472, -118.309)
# 6754     (34.0473, -118.2916)
# 6764     (34.0515, -118.3667)
# 8772     (34.0473, -118.2891)
# 10792    (34.0485, -118.3335)
# 48595     (34.042, -118.2625)
# 52701    (34.0401, -118.2668)
# 59546    (34.0467, -118.2814)
# 59550     (34.0472, -118.309)
# 59620     (34.0452, -118.419)
# 59677    (34.0369, -118.2607)
# 59755    (34.0479, -118.3447)
# 59847    (34.0437, -118.2748)
# 421749   (34.0363, -118.2672)
# 422058    (34.042, -118.2625)
# 422449    (34.042, -118.2625)
# 422741   (34.0389, -118.2643)
# 423804   (34.0335, -118.2619)
# 423847   (34.0395, -118.2656)
# 424476    (34.042, -118.2625)
# 424584   (34.0389, -118.2643)
# 424729   (34.0388, -118.2574)
# 424947   (34.0395, -118.2656)
# 425209    (34.042, -118.2625)
# 425233   (34.0352, -118.2583)
# 425589    (34.0407, -118.268)
# 425806   (34.0472, -118.2782)
# 425870   (34.0451, -118.2779)
# ...

# %%
dfpicoboul_1.describe()
# Out:
#        year_only    Latitude   Longitude
# count      613.0  613.000000  613.000000
# mean      2018.0   34.043335 -118.349859
# std          0.0    0.012398    0.068961
# min       2018.0   33.978600 -118.568900
# 25%       2018.0   34.036200 -118.429500
# 50%       2018.0   34.047200 -118.333500
# 75%       2018.0   34.047900 -118.291600
# max       2018.0   34.256700 -118.173900

# %%
dfpicoboul_1[['Latitude','Longitude']] = dfpicoboul_1.Location.str.split(",",expand=True,)
# Out:
# C:\Users\OLUFUNMILAYO\Anaconda3\lib\site-packages\pandas\core\frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
dfpicoboul_1.head()
# Out:
#                   Location  year_only  Latitude    Longitude
# 186   (34.0473, -118.2936)       2018  (34.0473   -118.2936)
# 4739  (34.0524, -118.4248)       2018  (34.0524   -118.4248)
# 6681   (34.0472, -118.309)       2018  (34.0472    -118.309)
# 6754  (34.0473, -118.2916)       2018  (34.0473   -118.2916)
# 6764  (34.0515, -118.3667)       2018  (34.0515   -118.3667)

# %%
dfpicoboul_1.dtypes
# Out:
# Location     object
# year_only     int64
# Latitude     object
# Longitude    object
# dtype: object

# %% [markdown]
# dfbradbuild.dropna(subset=["Location"], axis=0, inplace=True)
# #reset index, because we droped two rows
# dfbradbuild.reset_index(drop=True, inplace=True)

# %%
dfpicoboul_1['Latitude'] = dfpicoboul_1['Latitude'].map(lambda x: x.lstrip('(').rstrip(''))
# Out:
# C:\Users\OLUFUNMILAYO\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfpicoboul_1['Longitude'] = dfpicoboul_1['Longitude'].map(lambda x: x.lstrip('-').rstrip(')'))
# Out:
# C:\Users\OLUFUNMILAYO\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfpicoboul_1.head()
# Out:
#                   Location  year_only  Latitude   Longitude
# 186   (34.0473, -118.2936)       2018   34.0473   -118.2936
# 4739  (34.0524, -118.4248)       2018   34.0524   -118.4248
# 6681   (34.0472, -118.309)       2018   34.0472    -118.309
# 6754  (34.0473, -118.2916)       2018   34.0473   -118.2916
# 6764  (34.0515, -118.3667)       2018   34.0515   -118.3667

# %%
dfpicoboul_1['Latitude']=pd.to_numeric(dfpicoboul_1.Latitude)
dfpicoboul_1.dtypes
# Out:
# C:\Users\OLUFUNMILAYO\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# Location      object
# year_only      int64
# Latitude     float64
# Longitude     object
# dtype: object

# %%
dfpicoboul_1['Longitude']=pd.to_numeric(dfpicoboul_1.Longitude)
dfpicoboul_1.dtypes
# Out:
# C:\Users\OLUFUNMILAYO\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# Location      object
# year_only      int64
# Latitude     float64
# Longitude    float64
# dtype: object

# %%
dfpicoboul_1.head()
# Out:
#                   Location  year_only  Latitude  Longitude
# 186   (34.0473, -118.2936)       2018   34.0473  -118.2936
# 4739  (34.0524, -118.4248)       2018   34.0524  -118.4248
# 6681   (34.0472, -118.309)       2018   34.0472  -118.3090
# 6754  (34.0473, -118.2916)       2018   34.0473  -118.2916
# 6764  (34.0515, -118.3667)       2018   34.0515  -118.3667

# %%
dfpicoboul_1.dtypes
# Out:
# Location      object
# year_only      int64
# Latitude     float64
# Longitude    float64
# dtype: object

# %%
dfpicoboul_1['Latitudemean'] =dfpicoboul_1['Latitude'].mean()
# Out:
# C:\Users\OLUFUNMILAYO\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfpicoboul_1.head()
# Out:
#                   Location  year_only  Latitude  Longitude  Latitude1  \
# 186   (34.0473, -118.2936)       2018   34.0473  -118.2936  34.043335
# 4739  (34.0524, -118.4248)       2018   34.0524  -118.4248  34.043335
# 6681   (34.0472, -118.309)       2018   34.0472  -118.3090  34.043335
# 6754  (34.0473, -118.2916)       2018   34.0473  -118.2916  34.043335
# 6764  (34.0515, -118.3667)       2018   34.0515  -118.3667  34.043335
#
#       Latitudemean  Latitudestd  Longitudemean  Longitudestd
# 186      34.043335     0.012398    -118.349859      0.068961
# 4739     34.043335     0.012398    -118.349859      0.068961
# 6681     34.043335     0.012398    -118.349859      0.068961
# 6754     34.043335     0.012398    -118.349859      0.068961
# 6764     34.043335     0.012398    -118.349859      0.068961

# %%
dfpicoboul_1['Latitudestd'] =dfpicoboul_1['Latitude'].std()
# Out:
# C:\Users\OLUFUNMILAYO\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfpicoboul_1.head()
# Out:
#                   Location  year_only  Latitude  Longitude  Latitude1  \
# 186   (34.0473, -118.2936)       2018   34.0473  -118.2936  34.043335
# 4739  (34.0524, -118.4248)       2018   34.0524  -118.4248  34.043335
# 6681   (34.0472, -118.309)       2018   34.0472  -118.3090  34.043335
# 6754  (34.0473, -118.2916)       2018   34.0473  -118.2916  34.043335
# 6764  (34.0515, -118.3667)       2018   34.0515  -118.3667  34.043335
#
#       Latitudemean  Latitudestd  Longitudemean  Longitudestd
# 186      34.043335     0.012398    -118.349859      0.068961
# 4739     34.043335     0.012398    -118.349859      0.068961
# 6681     34.043335     0.012398    -118.349859      0.068961
# 6754     34.043335     0.012398    -118.349859      0.068961
# 6764     34.043335     0.012398    -118.349859      0.068961

# %%
dfpicoboul_1['Longitudemean'] =dfpicoboul_1['Longitude'].mean()
# Out:
# C:\Users\OLUFUNMILAYO\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfpicoboul_1.head()
# Out:
#                   Location  year_only  Latitude  Longitude  Latitude1  \
# 186   (34.0473, -118.2936)       2018   34.0473  -118.2936  34.043335
# 4739  (34.0524, -118.4248)       2018   34.0524  -118.4248  34.043335
# 6681   (34.0472, -118.309)       2018   34.0472  -118.3090  34.043335
# 6754  (34.0473, -118.2916)       2018   34.0473  -118.2916  34.043335
# 6764  (34.0515, -118.3667)       2018   34.0515  -118.3667  34.043335
#
#       Latitudemean  Latitudestd  Longitudemean  Longitudestd
# 186      34.043335     0.012398    -118.349859      0.068961
# 4739     34.043335     0.012398    -118.349859      0.068961
# 6681     34.043335     0.012398    -118.349859      0.068961
# 6754     34.043335     0.012398    -118.349859      0.068961
# 6764     34.043335     0.012398    -118.349859      0.068961

# %%
dfpicoboul_1['Longitudestd'] =dfpicoboul_1['Longitude'].std()
# Out:
# C:\Users\OLUFUNMILAYO\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfpicoboul_1.head()
# Out:
#                   Location  year_only  Latitude  Longitude  Latitude1  \
# 186   (34.0473, -118.2936)       2018   34.0473  -118.2936  34.043335
# 4739  (34.0524, -118.4248)       2018   34.0524  -118.4248  34.043335
# 6681   (34.0472, -118.309)       2018   34.0472  -118.3090  34.043335
# 6754  (34.0473, -118.2916)       2018   34.0473  -118.2916  34.043335
# 6764  (34.0515, -118.3667)       2018   34.0515  -118.3667  34.043335
#
#       Latitudemean  Latitudestd  Longitudemean  Longitudestd
# 186      34.043335     0.012398    -118.349859      0.068961
# 4739     34.043335     0.012398    -118.349859      0.068961
# 6681     34.043335     0.012398    -118.349859      0.068961
# 6754     34.043335     0.012398    -118.349859      0.068961
# 6764     34.043335     0.012398    -118.349859      0.068961

# %%
dfpicoboul_1['Longitudestd2'] =dfpicoboul_1['Longitudestd']*2
# Out:
# C:\Users\OLUFUNMILAYO\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfpicoboul_1.head()
# Out:
#                   Location  year_only  Latitude  Longitude  Latitude1  \
# 186   (34.0473, -118.2936)       2018   34.0473  -118.2936  34.043335
# 4739  (34.0524, -118.4248)       2018   34.0524  -118.4248  34.043335
# 6681   (34.0472, -118.309)       2018   34.0472  -118.3090  34.043335
# 6754  (34.0473, -118.2916)       2018   34.0473  -118.2916  34.043335
# 6764  (34.0515, -118.3667)       2018   34.0515  -118.3667  34.043335
#
#       Latitudemean  Latitudestd  Longitudemean  Longitudestd  Longitudestd2
# 186      34.043335     0.012398    -118.349859      0.068961       0.137922
# 4739     34.043335     0.012398    -118.349859      0.068961       0.137922
# 6681     34.043335     0.012398    -118.349859      0.068961       0.137922
# 6754     34.043335     0.012398    -118.349859      0.068961       0.137922
# 6764     34.043335     0.012398    -118.349859      0.068961       0.137922

# %%
dfpicoboul_1['Latitudestd2'] =dfpicoboul_1['Latitudestd']*2
# Out:
# C:\Users\OLUFUNMILAYO\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfpicoboul_1.head()
# Out:
#                   Location  year_only  Latitude  Longitude  Latitude1  \
# 186   (34.0473, -118.2936)       2018   34.0473  -118.2936  34.043335
# 4739  (34.0524, -118.4248)       2018   34.0524  -118.4248  34.043335
# 6681   (34.0472, -118.309)       2018   34.0472  -118.3090  34.043335
# 6754  (34.0473, -118.2916)       2018   34.0473  -118.2916  34.043335
# 6764  (34.0515, -118.3667)       2018   34.0515  -118.3667  34.043335
#
#       Latitudemean  Latitudestd  Longitudemean  Longitudestd  Longitudestd2  \
# 186      34.043335     0.012398    -118.349859      0.068961       0.137922
# 4739     34.043335     0.012398    -118.349859      0.068961       0.137922
# 6681     34.043335     0.012398    -118.349859      0.068961       0.137922
# 6754     34.043335     0.012398    -118.349859      0.068961       0.137922
# 6764     34.043335     0.012398    -118.349859      0.068961       0.137922
#
#       Latitudestd2
# 186       0.024795
# 4739      0.024795
# 6681      0.024795
# ...

# %%
dfpicoboul_1['Latitudeupper'] =dfpicoboul_1['Latitudemean'] + dfpicoboul_1['Latitudestd2']
dfpicoboul_1['Latitudelower'] =dfpicoboul_1['Latitudemean'] - dfpicoboul_1['Latitudestd2']
dfpicoboul_1['Longitudeupper'] =dfpicoboul_1['Longitudemean'] + dfpicoboul_1['Longitudestd2']
dfpicoboul_1['Longitudelower'] =dfpicoboul_1['Longitudemean'] - dfpicoboul_1['Longitudestd2']
# Out:
# C:\Users\OLUFUNMILAYO\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\OLUFUNMILAYO\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\OLUFUNMILAYO\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
dfpicoboul_1.head()
# Out:
#                   Location  year_only  Latitude  Longitude  Latitude1  \
# 186   (34.0473, -118.2936)       2018   34.0473  -118.2936  34.043335
# 4739  (34.0524, -118.4248)       2018   34.0524  -118.4248  34.043335
# 6681   (34.0472, -118.309)       2018   34.0472  -118.3090  34.043335
# 6754  (34.0473, -118.2916)       2018   34.0473  -118.2916  34.043335
# 6764  (34.0515, -118.3667)       2018   34.0515  -118.3667  34.043335
#
#       Latitudemean  Latitudestd  Longitudemean  Longitudestd  Longitudestd2  \
# 186      34.043335     0.012398    -118.349859      0.068961       0.137922
# 4739     34.043335     0.012398    -118.349859      0.068961       0.137922
# 6681     34.043335     0.012398    -118.349859      0.068961       0.137922
# 6754     34.043335     0.012398    -118.349859      0.068961       0.137922
# 6764     34.043335     0.012398    -118.349859      0.068961       0.137922
#
#       Latitudestd2  Latitudeupper  Latitudelower  Longitudeupper  \
# ...

# %%
dfpicoboul_2 =dfpicoboul_1[(dfpicoboul_1['Latitude'].between(34.01854, 34.06813))|(dfpicoboul_1['Longitude'].between(-118.487782, -118.211937))]

# %%
dfpicoboul_2.shape
# Out:
# (609, 3)

# %%
dfpicoboul_2.head()
# Out:
#                   Location  Latitude  Longitude
# 186   (34.0473, -118.2936)   34.0473  -118.2936
# 4739  (34.0524, -118.4248)   34.0524  -118.4248
# 6681   (34.0472, -118.309)   34.0472  -118.3090
# 6754  (34.0473, -118.2916)   34.0473  -118.2916
# 6764  (34.0515, -118.3667)   34.0515  -118.3667

# %%
dfpicoboul_2.drop(['year_only','Latitude1','Latitudemean','Latitudestd','Longitudemean','Longitudestd','Longitudestd2', 'Latitudestd2', 'Latitudeupper', 'Latitudelower', 'Longitudelower', 'Longitudeupper'], axis=1, inplace=True)

# %%
dfpicoboul_2.head()
# Out:
#                   Location  Latitude  Longitude
# 186   (34.0473, -118.2936)   34.0473  -118.2936
# 4739  (34.0524, -118.4248)   34.0524  -118.4248
# 6681   (34.0472, -118.309)   34.0472  -118.3090
# 6754  (34.0473, -118.2916)   34.0473  -118.2916
# 6764  (34.0515, -118.3667)   34.0515  -118.3667

# %%
dfpicoboul_2.max()
# Out:
# Location     (34.0814, -118.2962)
# Latitude                  34.0814
# Longitude                -118.216
# dtype: object

# %%
dfpicoboul_2.min()
# Out:
# Location     (33.9786, -118.2761)
# Latitude                  33.9786
# Longitude                -118.453
# dtype: object

# %%
from math import sin, cos, sqrt, atan2, radians


# approximate radius of earth in km
R = 6371.0

lat1 = radians(34.0814)
lon1 = radians(-118.216)
lat2 = radians(33.9786)
lon2 = radians(-118.453)

dlon = lon2 - lon1
dlat = lat2 - lat1

a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
c = 2 * atan2(sqrt(a), sqrt(1 - a))

distance = R * c

# %%
distance
# Out:
# 24.650604356217876

# %% [markdown]
# dfpicoboul_out1 = dfpicoboul_1.apply(lambda (x): x[(x < dfpicoboul_1[x.Latitude].mean()-2*dfpicoboul_1[x.Latitude].std()) & (x > dfpicoboul_1[x.Latitude].mean()+2*dfpicoboul_1[x.Latitude]std())], axis=0)
